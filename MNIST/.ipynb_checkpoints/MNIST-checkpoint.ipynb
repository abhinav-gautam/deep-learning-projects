# %% [markdown]
# # MNIST

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
# %matplotlib inline

# %%
mnist = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %% [markdown]
# ## Exploring Data

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
train_images[0].shape
# Out:
# (28, 28)

# %%
plt.imshow(train_images[0])
plt.colorbar()

# %%
plt.imshow(train_images[0],cmap=plt.cm.binary)

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
plt.imshow(train_images[1])
plt.colorbar()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i],cmap=plt.cm.binary)
    plt.xlabel(train_labels[i])
plt.show()

# %% [markdown]
# ## Building Model

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(128,activation='relu'))
model.add(keras.layers.Dense(128,activation='relu'))
model.add(keras.layers.Dense(128,activation='relu'))
model.add(keras.layers.Dense(10))
model.add(keras.layers.Softmax())

# %%
model.compile(optimizer="adam",loss="sparse_categorical_crossentropy",metrics=['accuracy'])

# %% [markdown]
# ## Training Model

# %%
model.fit(train_images,train_labels,epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.7265 - accuracy: 0.7615
# Epoch 2/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.3328 - accuracy: 0.9004
# Epoch 3/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.2450 - accuracy: 0.9260
# Epoch 4/10
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.1953 - accuracy: 0.9408
# Epoch 5/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.1619 - accuracy: 0.9506
# Epoch 6/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1376 - accuracy: 0.9584
# Epoch 7/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1220 - accuracy: 0.9627
# Epoch 8/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.1080 - accuracy: 0.9673
# Epoch 9/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0971 - accuracy: 0.9696
# Epoch 10/10
# 60000/60000 [==============================] - 4s 59us/sample - loss: 0.0887 - accuracy: 0.9728

# %% [markdown]
# ## Evaluating Accuracy

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels)
print("Test Loss:",test_loss,"\nTest Accuracy:",test_acc)
# Out:
# 10000/10000 [==============================] - 0s 40us/sample - loss: 0.1056 - accuracy: 0.9690
# Test Loss: 0.10559996280539781
# Test Accuracy: 0.969

# %% [markdown]
# ## Prediction

# %%
pred = model.predict([test_images])
print(np.argmax(pred[0]))
# Out:
# 7

# %%
plt.imshow(test_images[0],cmap=plt.cm.binary)
